# %%
import experimentation as exp
exp.run_ils_ada_25()
# Out:
# Running Adaptive ILS for 450 seconds...
# ILS - CPU Time: 450. Best Cut: 25.
# Adaptive ILS - CPU Time: 450. Best Cut: 25.
# Adaptive ILS - CPU Time: 450. Best Cut: 25.
# Running Adaptive ILS for 450 seconds...
# ILS - CPU Time: 450. Best Cut: 34.
# Adaptive ILS - CPU Time: 450. Best Cut: 34.
# Adaptive ILS - CPU Time: 450. Best Cut: 34.
# Running Adaptive ILS for 450 seconds...
# ILS - CPU Time: 450. Best Cut: 15.
# Adaptive ILS - CPU Time: 450. Best Cut: 15.
# Adaptive ILS - CPU Time: 450. Best Cut: 15.
# Running Adaptive ILS for 450 seconds...
# ILS - CPU Time: 450. Best Cut: 22.
# Adaptive ILS - CPU Time: 450. Best Cut: 22.
# Adaptive ILS - CPU Time: 450. Best Cut: 22.
# Running Adaptive ILS for 450 seconds...
# ILS - CPU Time: 450. Best Cut: 21.
# Adaptive ILS - CPU Time: 450. Best Cut: 21.
# Adaptive ILS - CPU Time: 450. Best Cut: 21.
# Running Adaptive ILS for 450 seconds...
# ILS - CPU Time: 450. Best Cut: 27.
# Adaptive ILS - CPU Time: 450. Best Cut: 27.
# ...
