# %%
import experimentation as exp
exp.run_ils(mutation_size=70, max_iterations=10000, runs=25, exp_name="ILS-25")
# Out:
# ILS - Mutation Size: 70. Best Cut: 10.
# ILS -0- Mutation Size: 70. Best Cut: 10.
# ILS - Mutation Size: 70. Best Cut: 12.
# ILS -1- Mutation Size: 70. Best Cut: 12.
# ILS - Mutation Size: 70. Best Cut: 8.
# ILS -2- Mutation Size: 70. Best Cut: 8.
# ILS - Mutation Size: 70. Best Cut: 9.
# ILS -3- Mutation Size: 70. Best Cut: 9.
# ILS - Mutation Size: 70. Best Cut: 13.
# ILS -4- Mutation Size: 70. Best Cut: 13.
# ILS - Mutation Size: 70. Best Cut: 7.
# ILS -5- Mutation Size: 70. Best Cut: 7.
# ILS - Mutation Size: 70. Best Cut: 10.
# ILS -6- Mutation Size: 70. Best Cut: 10.
# ILS - Mutation Size: 70. Best Cut: 8.
# ILS -7- Mutation Size: 70. Best Cut: 8.
# ILS - Mutation Size: 70. Best Cut: 7.
# ILS -8- Mutation Size: 70. Best Cut: 7.
# ILS - Mutation Size: 70. Best Cut: 11.
# ILS -9- Mutation Size: 70. Best Cut: 11.
# ILS - Mutation Size: 70. Best Cut: 8.
# ILS -10- Mutation Size: 70. Best Cut: 8.
# ILS - Mutation Size: 70. Best Cut: 12.
# ILS -11- Mutation Size: 70. Best Cut: 12.
# ...
